# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdellahZak/Fire-Vision/blob/main/firevision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fire vision, Machine learning project C946
#
# Data source: https://universe.roboflow.com/fire-detection/fire-data-annotations
# Data Type: unstructured Images

# %%
#!unzip /content/drive/MyDrive/FireVision/FireDataSet.zip -d /content/drive/MyDrive/FireVision

# %% [markdown]
# #Setup Workspace and code 😀

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import necessary stuff

import os
import tensorflow as tf
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
root_Folder='/content/drive/MyDrive/FireVision/train'

#Check GPU
print('GPU Tis available' if tf.config.list_physical_devices("GPU") else "not available")

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch
# Out:
# GPU Tis available

# %%
# Use the model
results = model.train(data=os.path.join(root_Folder, "google_colab_config.yaml"), epochs=10)  # train the model
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# ![train_batch2.jpg](data:image/jpeg;base64,...)![train_batch1.jpg](data:image/jpeg;base64,...)![train_batch0.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # test the model 🔥

# %%
infer= YOLO('/content/drive/MyDrive/FireVision/train/best.pt')

# %%
infer.predict('/content/drive/MyDrive/FireVision/test/images/MirrorWEBFire1696_jpg.rf.7e098d1f8da2b35c36d7a6a8dee41939.jpg', save=True, save_txt=True)
# Out:
# image 1/1 /content/drive/MyDrive/FireVision/test/images/MirrorWEBFire1696_jpg.rf.7e098d1f8da2b35c36d7a6a8dee41939.jpg: 384x640 1 fire, 60.3ms
# Speed: 4.2ms preprocess, 60.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 2 labels saved to runs/detect/predict/labels
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'fire'}
#  orig_img: array([[[229, 222, 203],
#          [229, 222, 203],
#          [229, 222, 203],
#          ...,
#          [235, 232, 224],
#          [236, 233, 225],
#          [237, 234, 226]],
#
#         [[230, 223, 204],
#          [230, 223, 204],
#          [230, 223, 204],
#          ...,
#          [235, 232, 224],
#          [237, 234, 226],
#          [237, 234, 226]],
#
#         [[230, 223, 204],
#          [230, 223, 204],
#          [230, 223, 204],
# ...

# %% [markdown]
# ![04886596873b4511_jpg.rf.a3f89833d649df02447d78c8bce0f2ce.jpg](data:image/jpeg;base64,...)![1135_jpg.rf.cdca50abdf838f669b6961a6394e5fe9.jpg](data:image/jpeg;base64,...)
